# %% [markdown]
# ### 03.smoking_and_age
#
# #### 🧩Purpose
# Identify the correlation between age&smking and insurance premiums.
#
# #### ✅Output
# 비흡연자들은 흡연자들보다 적은 보험료를 내고 있다. 또한 나이가 들수록 더 많은 보험료를 낸다.

# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read insurance.csv and store it in df

df=pd.read_csv('insurance.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
# lmplot을 사용하여 흡연자/비흡연자 그룹별로 나이와 보험료의 관계를 시각화
sns.lmplot(x='age', y='charges', hue='smoker', data=df)
plt.title('Relationship between age and insurance premiums according to smoking status')
plt.xlabel('Age')
plt.ylabel('Insurance cost')
plt.show()
